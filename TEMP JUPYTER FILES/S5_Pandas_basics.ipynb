# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('OfficeSupplies.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#       OrderDate   Region      Rep     Item  Units  Unit Price  Total Price  \
# 0    4-Jul-2014     East  Richard  Pen Set     62        4.99       309.38
# 1   12-Jul-2014     East     Nick   Binder     29        1.99        57.71
# 2   21-Jul-2014  Central   Morgan  Pen Set     55       12.49       686.95
# 3   29-Jul-2014     East    Susan   Binder     81       19.99      1619.19
# 4    7-Aug-2014  Central  Matthew  Pen Set     42       23.95      1005.90
# 5   15-Aug-2014     East  Richard   Pencil     35        4.99       174.65
# 6   24-Aug-2014     West    James     Desk      3      275.00       825.00
# 7    1-Sep-2014  Central    Smith     Desk      2      125.00       250.00
# 8   10-Sep-2014  Central     Bill   Pencil      7        1.29         9.03
# 9   18-Sep-2014     East  Richard  Pen Set     16       15.99       255.84
# 10  27-Sep-2014     West    James      Pen     76        1.99       151.24
# ...

# %%
data.tail(2)
# Out:
#       OrderDate   Region      Rep    Item  Units  Unit Price
# 41  17-Jun-2015  Central  Matthew    Desk      5      125.00
# 42  25-Jun-2015  Central   Morgan  Pencil     90        4.99

# %%
# Next session
# pandas slicing & dicing: to extract data from the dataframe

# %%
# slice a full column

# %%
data['OrderDate']
# Out:
# 0      4-Jul-2014
# 1     12-Jul-2014
# 2     21-Jul-2014
# 3     29-Jul-2014
# 4      7-Aug-2014
# 5     15-Aug-2014
# 6     24-Aug-2014
# 7      1-Sep-2014
# 8     10-Sep-2014
# 9     18-Sep-2014
# 10    27-Sep-2014
# 11     5-Oct-2014
# 12    14-Oct-2014
# 13    22-Oct-2014
# 14    31-Oct-2014
# 15     8-Nov-2014
# 16    17-Nov-2014
# 17    25-Nov-2014
# 18     4-Dec-2014
# 19    12-Dec-2014
# 20    21-Dec-2014
# 21    29-Dec-2014
# 22     6-Jan-2015
# 23    15-Jan-2015
# 24    23-Jan-2015
# 25     1-Feb-2015
# 26     9-Feb-2015
# 27    18-Feb-2015
# 28    26-Feb-2015
# 29     7-Mar-2015
# 30    15-Mar-2015
# 31    24-Mar-2015
# 32     1-Apr-2015
# 33    10-Apr-2015
# 34    18-Apr-2015
# 35    27-Apr-2015
# 36     5-May-2015
# 37    14-May-2015
# 38    22-May-2015
# 39    31-May-2015
# 40     8-Jun-2015
# 41    17-Jun-2015
# 42    25-Jun-2015
# Name: OrderDate, dtype: object

# %%
data.head(2)
# Out:
#      OrderDate Region      Rep     Item  Units  Unit Price
# 0   4-Jul-2014   East  Richard  Pen Set     62        4.99
# 1  12-Jul-2014   East     Nick   Binder     29        1.99

# %%
data['Total Price'] = data['Units']*data['Unit Price']

# %%
data.head(2)
# Out:
#      OrderDate Region      Rep     Item  Units  Unit Price  Total Price
# 0   4-Jul-2014   East  Richard  Pen Set     62        4.99       309.38
# 1  12-Jul-2014   East     Nick   Binder     29        1.99        57.71

# %%
data['Total Price (discounted 10%)'] = data['Total Price']*0.9

# %%
data.head(2)
# Out:
#      OrderDate Region      Rep     Item  Units  Unit Price  Total Price  \
# 0   4-Jul-2014   East  Richard  Pen Set     62        4.99       309.38
# 1  12-Jul-2014   East     Nick   Binder     29        1.99        57.71
#
#    Total Price (discounted 10%)
# 0                       278.442
# 1                        51.939

# %%
# Sum of Total Price for each region (East, West and Central)

# %%
# Sales by Region (X=1, Y=1)

# %%
data.groupby('Region')['Total Price'].sum() #data.groupby(Column to group)[numeric column to perform some calculation].sum()
# Out:
# Region
# Central    11139.07
# East        6002.09
# West        2486.72
# Name: Total Price, dtype: float64

# %%
data.groupby('Rep')['Total Price'].sum()
# Out:
# Rep
# Alex       2812.19
# Bill       1749.87
# James      1283.61
# Matthew    3109.44
# Morgan     1387.77
# Nick        536.75
# Rachel      438.37
# Richard    2363.04
# Smith      1641.43
# Susan      3102.30
# Thomas     1203.11
# Name: Total Price, dtype: float64

# %%
data.groupby('Rep')['Total Price'].sum().sort_index(ascending=False)
# Out:
# Rep
# Thomas     1203.11
# Susan      3102.30
# Smith      1641.43
# Richard    2363.04
# Rachel      438.37
# Nick        536.75
# Morgan     1387.77
# Matthew    3109.44
# James      1283.61
# Bill       1749.87
# Alex       2812.19
# Name: Total Price, dtype: float64

# %%
# Indexing = index values
# Values

# %%
# Data Annotations/Conventions

# Dimensions = X = Qualitative (String)
# Fact = Y = (Numeric)

# %%
# Sales by Rep (X=1, Y=1)

# %%
data.groupby('Rep')['Total Price'].sum().sort_values(ascending=False)
# Out:
# Rep
# Matthew    3109.44
# Susan      3102.30
# Alex       2812.19
# Richard    2363.04
# Bill       1749.87
# Smith      1641.43
# Morgan     1387.77
# James      1283.61
# Thomas     1203.11
# Nick        536.75
# Rachel      438.37
# Name: Total Price, dtype: float64

# %%
# Sales by Region and Rep (X=2, Y=1)

# %%
data.groupby(['Region', 'Rep'])['Total Price'].sum()
# Out:
# Region   Rep
# Central  Alex       2812.19
#          Bill       1749.87
#          Matthew    3109.44
#          Morgan     1387.77
#          Rachel      438.37
#          Smith      1641.43
# East     Nick        536.75
#          Richard    2363.04
#          Susan      3102.30
# West     James      1283.61
#          Thomas     1203.11
# Name: Total Price, dtype: float64

# %%
pd.DataFrame(data.groupby(['Region', 'Rep'])['Total Price'].sum())
# Out:
#                  Total Price
# Region  Rep
# Central Alex         2812.19
#         Bill         1749.87
#         Matthew      3109.44
#         Morgan       1387.77
#         Rachel        438.37
#         Smith        1641.43
# East    Nick          536.75
#         Richard      2363.04
#         Susan        3102.30
# West    James        1283.61
#         Thomas       1203.11

# %%
# Sales & Quantity by Region and Rep (X=2, Y=1)

# %%
data.groupby(['Region', 'Rep'])['Total Price', 'Units'].sum()
# Out:
# C:\Users\ajitp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                  Total Price  Units
# Region  Rep
# Central Alex         2812.19    281
#         Bill         1749.87    213
#         Matthew      3109.44    193
#         Morgan       1387.77    173
#         Rachel        438.37    183
#         Smith        1641.43    156
# East    Nick          536.75    125
#         Richard      2363.04    396
#         Susan        3102.30    170
# West    James        1283.61    142
#         Thomas       1203.11     89

# %%
data.sort_values('Total Price')
# Out:
#       OrderDate   Region      Rep     Item  Units  Unit Price  Total Price  \
# 8   10-Sep-2014  Central     Bill   Pencil      7        1.29         9.03
# 14  31-Oct-2014  Central   Rachel   Pencil     14        1.29        18.06
# 27  18-Feb-2015     East  Richard   Binder      4        4.99        19.96
# 16  17-Nov-2014  Central     Alex   Binder     11        4.99        54.89
# 1   12-Jul-2014     East     Nick   Binder     29        1.99        57.71
# 38  22-May-2015     West   Thomas   Pencil     32        1.99        63.68
# 37  14-May-2015  Central     Bill   Pencil     53        1.29        68.37
# 19  12-Dec-2014  Central    Smith   Pencil     67        1.29        86.43
# 33  10-Apr-2015  Central   Rachel   Pencil     66        1.99       131.34
# 20  21-Dec-2014  Central   Rachel   Binder     28        4.99       139.72
# 29   7-Mar-2015     West    James   Binder      7       19.99       139.93
# ...

# %%
# Sales by Region

# %%
data.groupby('Region')['Total Price'].sum()
# Out:
# Region
# Central    11139.07
# East        6002.09
# West        2486.72
# Name: Total Price, dtype: float64

# %%
# Sales by Rep

# %%
# Sales by Item

# %%
# Quantity/Units by Region

# %%
# Average Item Price by Region

# %%
data.groupby(['Region','Item'])['Unit Price'].mean()
# Out:
# Region   Item
# Central  Binder      11.491250
#          Desk       125.000000
#          Pen         19.990000
#          Pen Set     11.605000
#          Pencil       2.678889
# East     Binder       8.190000
#          Pen         11.323333
#          Pen Set     12.323333
#          Pencil       3.490000
# West     Binder      19.990000
#          Desk       275.000000
#          Pen          1.990000
#          Pencil       2.490000
# Name: Unit Price, dtype: float64
