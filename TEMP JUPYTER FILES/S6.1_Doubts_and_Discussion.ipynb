# %%
# import for pandas and numpy

# %%
import pandas as pd
import numpy as np

# %%
bc = pd.read_csv('BankChurners.csv')

# %%
bc.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
bc['CLIENTNUM']
# Out:
# 0        768805383
# 1        818770008
# 2        713982108
# 3        769911858
# 4        709106358
#            ...
# 10122    772366833
# 10123    710638233
# 10124    716506083
# 10125    717406983
# 10126    714337233
# Name: CLIENTNUM, Length: 10127, dtype: int64

# %%
bc['CLIENTNUM'].head(6)
# Out:
# 0    768805383
# 1    818770008
# 2    713982108
# 3    769911858
# 4    709106358
# 5    713061558
# Name: CLIENTNUM, dtype: int64

# %%
bc[['CLIENTNUM', 'Attrition_Flag']].tail(10)
# Out:
#        CLIENTNUM     Attrition_Flag
# 10117  712503408  Existing Customer
# 10118  713755458  Attrited Customer
# 10119  716893683  Attrited Customer
# 10120  710841183  Existing Customer
# 10121  713899383  Existing Customer
# 10122  772366833  Existing Customer
# 10123  710638233  Attrited Customer
# 10124  716506083  Attrited Customer
# 10125  717406983  Attrited Customer
# 10126  714337233  Attrited Customer

# %%
# When did the first customer

# %%
# head and tail both are useful to understand the data

# %%
bc.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
bc.tail()
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  \
# ...

# %%
bc.head() #When you want to see the origin of data #interestd in early customers in a day when you data file is extracted daily

# %%
bc.tail() #data is transactional, and you're interested in the recent transactions.

# %%
bc.tail()
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  \
# ...

# %%
# slicing: you want to extract a set of rows from a dataframe. Its like extracting a sub-dataframe from a dataframe.

# %%
bc[1:5] #its the kind of best method, when you want to extract rows with all columns.
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 1              44  ...        8256.0                  864           7392.0
# 2              36  ...        3418.0                    0           3418.0
# ...

# %%
bc[::3] #its more like step data, you can extract rows in any fixed step/window fashion.
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 3      769911858  Existing Customer            40      F                4
# 6      810347208  Existing Customer            51      M                4
# 9      719661558  Existing Customer            48      M                2
# 12     710599683  Existing Customer            56      M                1
# ...          ...                ...           ...    ...              ...
# 10113  713733633  Attrited Customer            27      M                0
# 10116  714109308  Existing Customer            46      M                5
# 10119  716893683  Attrited Customer            55      F                3
# 10122  772366833  Existing Customer            50      M                2
# 10125  717406983  Attrited Customer            30      M                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
# extract columns by number

# %%
bc.iloc[1:5, 0:5] #bc.iloc[rows, column] #iloc: indexing based location
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3

# %%
bc.iloc[0:5, [0,7]] #bc.iloc[rows_range, columns_number_selectors_in_the_form_of_a_list]
# Out:
#    CLIENTNUM Income_Category
# 0  768805383     $60K - $80K
# 1  818770008  Less than $40K
# 2  713982108    $80K - $120K
# 3  769911858  Less than $40K
# 4  709106358     $60K - $80K

# %%
bc.loc[0:5, ['CLIENTNUM','Income_Category']]
# Out:
#    CLIENTNUM Income_Category
# 0  768805383     $60K - $80K
# 1  818770008  Less than $40K
# 2  713982108    $80K - $120K
# 3  769911858  Less than $40K
# 4  709106358     $60K - $80K
# 5  713061558     $40K - $60K

# %%
bc.iloc[:, [0,7]]
# Out:
#        CLIENTNUM Income_Category
# 0      768805383     $60K - $80K
# 1      818770008  Less than $40K
# 2      713982108    $80K - $120K
# 3      769911858  Less than $40K
# 4      709106358     $60K - $80K
# ...          ...             ...
# 10122  772366833     $40K - $60K
# 10123  710638233     $40K - $60K
# 10124  716506083  Less than $40K
# 10125  717406983     $40K - $60K
# 10126  714337233  Less than $40K
#
# [10127 rows x 2 columns]

# %%
#bc.groupby(['Axis'])['Measure'].aggregation_function()

# %%
bc.groupby(['Income_Category'])['Total_Trans_Amt'].mean()
# Out:
# Income_Category
# $120K +           4529.467675
# $40K - $60K       4405.618994
# $60K - $80K       4450.712553
# $80K - $120K      4482.960261
# Less than $40K    4363.420107
# Unknown           4282.211331
# Name: Total_Trans_Amt, dtype: float64

# %%
#10 rows from first column, 5 rows from second column

# %%
bc.iloc[:10, :2]
# Out:
#    CLIENTNUM     Attrition_Flag
# 0  768805383  Existing Customer
# 1  818770008  Existing Customer
# 2  713982108  Existing Customer
# 3  769911858  Existing Customer
# 4  709106358  Existing Customer
# 5  713061558  Existing Customer
# 6  810347208  Existing Customer
# 7  818906208  Existing Customer
# 8  710930508  Existing Customer
# 9  719661558  Existing Customer

# %%
bc.iloc[:10, :2]
# Out:
#    CLIENTNUM     Attrition_Flag
# 0  768805383  Existing Customer
# 1  818770008  Existing Customer
# 2  713982108  Existing Customer
# 3  769911858  Existing Customer
# 4  709106358  Existing Customer
# 5  713061558  Existing Customer
# 6  810347208  Existing Customer
# 7  818906208  Existing Customer
# 8  710930508  Existing Customer
# 9  719661558  Existing Customer

# %%
bc.iloc[:5, :2]
# Out:
#    CLIENTNUM     Attrition_Flag
# 0  768805383  Existing Customer
# 1  818770008  Existing Customer
# 2  713982108  Existing Customer
# 3  769911858  Existing Customer
# 4  709106358  Existing Customer
# 5  713061558  Existing Customer
# 6  810347208  Existing Customer
# 7  818906208  Existing Customer
# 8  710930508  Existing Customer
# 9  719661558  Existing Customer

# %%
bc.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
bc.groupby(['Income_Category'])[['Customer_Age','Dependent_count']].mean()
# Out:
#                  Customer_Age  Dependent_count
# Income_Category
# $120K +             47.603851         2.462173
# $40K - $60K         46.087151         2.308380
# $60K - $80K         45.968616         2.440086
# $80K - $120K        46.428013         2.492508
# Less than $40K      46.297950         2.263690
# Unknown             46.274281         2.275180

# %%
bc.groupby(['Education_Level'])[['Customer_Age','Dependent_count']].mean()
# Out:
#                  Customer_Age  Dependent_count
# Education_Level
# College             45.970385         2.359329
# Doctorate           47.261641         2.325942
# Graduate            46.323529         2.347506
# High School         46.345256         2.311972
# Post-Graduate       45.562016         2.399225
# Uneducated          46.423672         2.353060
# Unknown             46.428571         2.361422

# %%
#PRNG (Pseudo Random Number Generator, that uses Permutation and Combination in normally distributed environment)

# %%
bc.isna().sum() #Missing value analysis
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %%
bc.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
bc.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
credit = pd.read_csv('credit_train.csv')

# %%
credit.isna().sum()
# Out:
# Loan ID                           514
# Customer ID                       514
# Loan Status                       514
# Current Loan Amount               514
# Term                              514
# Credit Score                    19668
# Annual Income                   19668
# Years in current job             4736
# Home Ownership                    514
# Purpose                           514
# Monthly Debt                      514
# Years of Credit History           514
# Months since last delinquent    53655
# Number of Open Accounts           514
# Number of Credit Problems         514
# Current Credit Balance            514
# Maximum Open Credit               516
# Bankruptcies                      718
# Tax Liens                         524
# dtype: int64

# %%
credit.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048  981165ec-3274-42f5-a3b4-d104041a9ca9
# 1  4771cc26-131a-45db-b5aa-537ea4ba5342  2de017a3-2e01-49cb-a581-08169e83be29
# 2  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26  5efb2b2b-bf11-4dfd-a572-3761a2694725
# 3  77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a  e777faab-98ae-45af-9a86-7ce5b33b1011
# 4  d4062e70-befa-4995-8643-a0de73938182  81536ad9-5ccf-4eb8-befb-47a4d608658e
#
#   Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# 0  Fully Paid             445412.0  Short Term         709.0      1167493.0
# 1  Fully Paid             262328.0  Short Term           NaN            NaN
# 2  Fully Paid           99999999.0  Short Term         741.0      2231892.0
# 3  Fully Paid             347666.0   Long Term         721.0       806949.0
# 4  Fully Paid             176220.0  Short Term           NaN            NaN
#
# ...

# %%
credit[credit['Current Loan Amount'].isna()].to_excel('Output.xls')

# %%
credit1 = credit[:100000].copy()

# %%
credit1.isna().sum()
# Out:
# Loan ID                             0
# Customer ID                         0
# Loan Status                         0
# Current Loan Amount                 0
# Term                                0
# Credit Score                    19154
# Annual Income                   19154
# Years in current job             4222
# Home Ownership                      0
# Purpose                             0
# Monthly Debt                        0
# Years of Credit History             0
# Months since last delinquent    53141
# Number of Open Accounts             0
# Number of Credit Problems           0
# Current Credit Balance              0
# Maximum Open Credit                 2
# Bankruptcies                      204
# Tax Liens                          10
# dtype: int64

# %%
credit.isna().sum()
# Out:
# Loan ID                           514
# Customer ID                       514
# Loan Status                       514
# Current Loan Amount               514
# Term                              514
# Credit Score                    19668
# Annual Income                   19668
# Years in current job             4736
# Home Ownership                    514
# Purpose                           514
# Monthly Debt                      514
# Years of Credit History           514
# Months since last delinquent    53655
# Number of Open Accounts           514
# Number of Credit Problems         514
# Current Credit Balance            514
# Maximum Open Credit               516
# Bankruptcies                      718
# Tax Liens                         524
# dtype: int64

# %%
# How to use pandas for simple reporting?

# how you import pandas
# how to load the data
# univariate analysis of a categorical colum, how to generate a bar graph
# univariate analysis of numeric column: how you can calculate five number summary of a numeric column, how to generate a histogram or boxplot [or linegraph]
# How to find the number if missing values on each column?
# Let's meet in next blog
