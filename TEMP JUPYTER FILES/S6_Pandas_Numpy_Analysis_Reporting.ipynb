# %%
# Data Analysis

# Run algorithm on the data, like ML

# %%
# Data Reporting

# Representation of the output

# %%
# Data Reporting - Business

# Sources: DBMS (Data Base Management System) >> Structured Data (Tabular Data) >> MySQL, Oracle 10g/11g, MS SQL, Azure SQL, Amazon Redshift, etc.
# Structural Query Language (SQL) 

# Telling something about the business without looking too deep into the data
# How many products are sold on a day?
# How many products were sold last week?
# What is the week over week sales performance?
# How many packages were processed by Receiving department last month?
# How many packages were processed by Receiving department last month on an per day average, or hourly average?
# Metrics / Key Performance Indicator (KPI)
# The metrics in business are mostly simple, and used to measure something quantatively.
# For sale, what can be good metric?
# NoOfSales: hourly, daily, weekly, monthly, quarterly, yearly, etc
# NoOfAddToCarts - NoOfCheckouts - DaysInCart
# Growth Hacking (Social Dilemma) -- Advanced Reporting, Analytics & Machine Learning

# %%
# Data Analysis - Business

# Ottawa, Temperature, Rain/Heat, Month -- Sunny, Scorching or something like that
# Reading between the lines
# Data of many customer who made some purchases on our platform
# Attributes:- age, gender, working domain, region, income segment, some other lifestyle data (Behaviour/Demographic Analysis)

# %%
# Exploratory Data Analysis (EDA) - Data validation, Data Preparation for something like ML, Reporting, etc.

# Acquiring/Loading the data
# Univariate Analysis
# Bivariate Analysis
# Multivariate Analysis
# Cleaning data
# Handling Missing Data
# Analyzing data
# Feature Engineering - Adding an addition column to structured data to increase the accuracy or improve elapsed time of a data process 
# Data Preparation
# Data Validation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\ajitp\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
dat = pd.read_csv('BankChurners.csv')

# %%
dat.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
dat.isna().sum() #na -- nan -- not a number -- empty value
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %%
house = pd.read_csv('house_pricing_train.csv')

# %%
house.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house.head().isna().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# Alley            5
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# ...

# %%
house['FireplaceQu'].head()
# Out:
# 0    NaN
# 1     TA
# 2     TA
# 3     Gd
# 4     TA
# Name: FireplaceQu, dtype: object

# %%
pd.options.display.max_rows = 4000

# %%
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# <ipython-input-19-69e616c06588> in <module>
# ----> 1 pd.options.display.max_cols = 100
#
# ~\Anaconda3\lib\site-packages\pandas\_config\config.py in __setattr__(self, key, val)
#     194             _set_option(prefix, val)
#     195         else:
# --> 196             raise OptionError("You can only set the value of existing options")
#     197
#     198     def __getattr__(self, key: str):
#
# OptionError: 'You can only set the value of existing options'

# %%
output = house.isna().sum()

# %%
output['LotFrontage']
# Out:
# 259

# %%
output[3]
# Out:
# 259

# %%
for name in output.index:
    if output[name]>0:
        print (name + ': \t' + str(output[name]))
# Out:
# LotFrontage: 	259
# Alley: 	1369
# MasVnrType: 	8
# MasVnrArea: 	8
# BsmtQual: 	37
# BsmtCond: 	37
# BsmtExposure: 	38
# BsmtFinType1: 	37
# BsmtFinType2: 	38
# Electrical: 	1
# FireplaceQu: 	690
# GarageType: 	81
# GarageYrBlt: 	81
# GarageFinish: 	81
# GarageQual: 	81
# GarageCond: 	81
# PoolQC: 	1453
# Fence: 	1179
# MiscFeature: 	1406

# %%
for num in range(len(output)):
    if output[num]>0:
        print (output.index[num] + ':' + str(output[num]))
# Out:
# LotFrontage:259
# Alley:1369
# MasVnrType:8
# MasVnrArea:8
# BsmtQual:37
# BsmtCond:37
# BsmtExposure:38
# BsmtFinType1:37
# BsmtFinType2:38
# Electrical:1
# FireplaceQu:690
# GarageType:81
# GarageYrBlt:81
# GarageFinish:81
# GarageQual:81
# GarageCond:81
# PoolQC:1453
# Fence:1179
# MiscFeature:1406

# %%
output[output>0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
house.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
type(output)
# Out:
# pandas.core.series.Series

# %%
type(house)
# Out:
# pandas.core.frame.DataFrame

# %%
house[house.MSSubClass==60]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# 20      21          60       RL        101.0    14215   Pave   NaN      IR1
# 35      36          60       RL        108.0    13418   Pave   NaN      Reg
# 50      51          60       RL          NaN    13869   Pave   NaN      IR2
# 57      58          60       RL         89.0    11645   Pave   NaN      IR1
# 58      59          60       RL         66.0    13682   Pave   NaN      IR2
# 64      65          60       RL          NaN     9375   Pave   NaN      Reg
# ...

# %%
house[house['MSSubClass']==60]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# 20      21          60       RL        101.0    14215   Pave   NaN      IR1
# 35      36          60       RL        108.0    13418   Pave   NaN      Reg
# 50      51          60       RL          NaN    13869   Pave   NaN      IR2
# 57      58          60       RL         89.0    11645   Pave   NaN      IR1
# 58      59          60       RL         66.0    13682   Pave   NaN      IR2
# 64      65          60       RL          NaN     9375   Pave   NaN      Reg
# ...

# %%
house1 = house.copy()

# %%
house1 = house1.rename(columns={'MSSubClass' : 'MS SubClass'})

# %%
house1.head()
# Out:
#    Id  MS SubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1           60       RL         65.0     8450   Pave   NaN      Reg
# 1   2           20       RL         80.0     9600   Pave   NaN      Reg
# 2   3           60       RL         68.0    11250   Pave   NaN      IR1
# 3   4           70       RL         60.0     9550   Pave   NaN      IR1
# 4   5           60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house1[house1['MS SubClass']==60]
# Out:
#         Id  MS SubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1           60       RL         65.0     8450   Pave   NaN      Reg
# 2        3           60       RL         68.0    11250   Pave   NaN      IR1
# 4        5           60       RL         84.0    14260   Pave   NaN      IR1
# 7        8           60       RL          NaN    10382   Pave   NaN      IR1
# 11      12           60       RL         85.0    11924   Pave   NaN      IR1
# 20      21           60       RL        101.0    14215   Pave   NaN      IR1
# 35      36           60       RL        108.0    13418   Pave   NaN      Reg
# 50      51           60       RL          NaN    13869   Pave   NaN      IR2
# 57      58           60       RL         89.0    11645   Pave   NaN      IR1
# 58      59           60       RL         66.0    13682   Pave   NaN      IR2
# 64      65           60       RL          NaN     9375   Pave   NaN      Reg
# ...

# %%
house1 = house1.rename(columns={'MS SubClass': 'MSSubClass'})

# %%
house1.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# Acquiring/Loading the data -- Done -- pd.read_x
# Check the missing values   -- Done -- isna().sum()
# Univariate Analysis        -- Analysis of one column
# Bivariate Analysis
# Multivariate Analysis
# Cleaning data              -- Basic
# Handling Missing Data      --  
# Analyzing data
# Feature Engineering - Adding an addition column to structured data to increase the accuracy or improve elapsed time of a data process 
# Data Preparation
# Data Validation

# %%
output = house.isna().sum()
output[output>0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
# Univariate Analysis
# Categorical (Number or String)
# Numerical (Continuous or Discrete)

# %%
house.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
len(house.Id)/len(house)
# Out:
# 1.0

# %%
len(house.LotArea)/len(house)
# Out:
# 1.0

# %%
house.MSZoning.unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
house.MSSubClass.unique()
# Out:
# array([ 60,  20,  70,  50, 190,  45,  90, 120,  30,  85,  80, 160,  75,
#        180,  40], dtype=int64)

# %%
house.MSZoning.value_counts()
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
(house.MSSubClass.value_counts()/len(house))*100
# Out:
# 20     36.712329
# 60     20.479452
# 50      9.863014
# 120     5.958904
# 30      4.726027
# 160     4.315068
# 70      4.109589
# 80      3.972603
# 90      3.561644
# 190     2.054795
# 85      1.369863
# 75      1.095890
# 45      0.821918
# 180     0.684932
# 40      0.273973
# Name: MSSubClass, dtype: float64

# %%
len(house.MSSubClass.unique())/len(house)*100
# Out:
# 1.0273972602739725

# %%
len(house.LotArea.unique())/len(house)*100
# Out:
# 73.4931506849315

# %%
# Visualization of a column/variable (Univariate Analysis)

# %%
# For the categorical columns, frequency table is the most common data summary
# Hence, bar graph is the most appropriate way to show this data.

# %%
house.MSSubClass.value_counts().sort_index().plot(kind='bar')

# %%
# For the continuous columns, frequency table can be still used, but for the histogram/distribution of the data.
# Hence, histogram is the most appropriate way to show this data.

# %%
house.LotArea.plot(kind='hist', bins=30)

# %%
# Boxplot can make more sense for continuous data

house.LotArea.plot(kind='box')

# %%
len(house.LotArea)
# Out:
# 1460

# %%
len(house.LotArea[house.LotArea<100000])
# Out:
# 1456

# %%
house.LotArea[house.LotArea<100000].plot(kind='box')

# %%
house.LotArea[(house.LotArea>20000) & (house.LotArea<100000)].plot(kind='box')

# %%
# TAKE THIS INTO CONSIDERATION WHEN PRESENTING YOUR DATA TO STAKEHOLDERS

# Rule/Assumption
# Inclusions: (LotArea<100000)
# Exclusions: (LotArea>=100000)
# Reason: Only 4 values are out of (LotArea<100000) range

# %%
# RULES ARE

# Categorical Data: 
#                           Frequency Table
#                           Bar Graph
# Continuous/Discrete Data: 
#                           Frequency Table (Grouped) -- Histogram
#                           Box Plot
#                           Five Number Summary

# %%
# ?pd.Series

# %%
pd.Series(data=[house.LotArea.min(),house.LotArea.mean(),house.LotArea.median(),house.LotArea.std(),house.LotArea.max()], 
          index=['Min','Mean','Median','Stddev','Max'])
# Out:
# Min         1300.000000
# Mean       10516.828082
# Median      9478.500000
# Stddev      9981.264932
# Max       215245.000000
# dtype: float64

# %%
house.MSZoning.value_counts()
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
house.MSZoning.value_counts().plot(kind='bar')

# %%
house.MSZoning.value_counts().sort_values().plot(kind='bar')

# %%
house.MSZoning.value_counts().sort_index().plot(kind='bar')
